# %% [markdown]
# ## Preliminary analysis
#
# This notebook analyzes the MTA subway data for the week of June 10-17, 2017 that can be found here:
#
# http://web.mta.info/developers/turnstile.html
#
# 1.Download that SAME file and read it in below. View the first few rows.

# %%
import pandas as pd 
mta = pd.read_csv('Subway Dataset.txt')
mta.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/10/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/10/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/10/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/10/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/10/2017  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6215258
# 1  REGULAR  6215284
# 2  REGULAR  6215318
# 3  REGULAR  6215475
# 4  REGULAR  6215841
#
#    EXITS
# 0                                            2104297
# 1                                            2104303
# 2                                            2104337
# 3                                            2104417
# 4                                            2104465

# %% [markdown]
# 2.What are the column names?

# %%
print(mta.columns)
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %% [markdown]
# 3.We can see that there is a lot of whitespace at the end of the exits column name. Let's strip that whitespace:

# %%
mta.columns = mta.columns.str.strip()
print(mta.columns)
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %% [markdown]
# 4.How big is the data set?

# %%
print(mta.shape)
# Out:
# (197209, 11)

# %% [markdown]
# 5.How many unique stations are there? What are they? Answer each of these questions in one line each.

# %%
print(len(mta.groupby('STATION')))
mta.groupby('STATION').sum()
# Out:
# 376
#                       ENTRIES         EXITS
# STATION
# 1 AV              58586439499   60761722844
# 103 ST             6159546302   25497370998
# 103 ST-CORONA      2961250139    2761521588
# 104 ST           203476432319  147939061941
# 110 ST             1307707035    1284447484
# 111 ST             6665357833    3314314817
# 116 ST            72001108475   87046842590
# 116 ST-COLUMBIA   51079934270   10887681396
# 121 ST              342679611     271293506
# 125 ST           284655484824  163343743843
# 135 ST            10280716722    1926220076
# 137 ST CITY COL   10292058587   37027121435
# 138/GRAND CONC    41901321363   40459308765
# 14 ST            170782461860  122561206314
# 14 ST-UNION SQ    46934618524   13167887414
# 145 ST            39082866901   82582949272
# 149/GRAND CONC    13211801088    8824078973
# 14TH STREET          53451236     112389461
# 15 ST-PROSPECT    14704689818     239067645
# 155 ST             1425110065    1071605945
# 157 ST             1476638165     919029595
# 161/YANKEE STAD   87280549993   57336769569
# 163 ST-AMSTERDM   82794446686   28397224550
# 167 ST            82001627844   39262879466
# 168 ST             6174310954    2818551685
# 169 ST             1120360388    1128112640
# 170 ST            48464654765   99304320246
# 174 ST            31411608037   14020852901
# 174-175 STS         719619033     454246119
# 175 ST            15823482530   12857307765
# ...                       ...           ...
# SUTPHIN-ARCHER     9779416519    4147175214
# SUTTER AV            37371994      12020871
# SUTTER AV-RUTLD     399979356     228787269
# THIRTY ST           264991012     276579981
# THIRTY THIRD ST     421584540     297414333
# TIMES SQ-42 ST   248249302084  193002230465
# TOMPKINSVILLE       375095461      99361232
# TREMONT AV         6989229055     680530128
# TWENTY THIRD ST     138094629     107395290
# UNION ST            955688517     994528736
# UTICA AV           8305042963    2289853007
# V.CORTLANDT PK      793702231     325857689
# VAN SICLEN AV      1119704797     958495549
# VAN SICLEN AVE      480023449     494489247
# VERNON-JACKSON     1606982170    1110264986
# W 4 ST-WASH SQ    15992153479    6056060748
# W 8 ST-AQUARIUM     501788066     535496710
# WAKEFIELD/241       764025616     785365568
# WALL ST           27590615954   16302950935
# WEST FARMS SQ     18349126515    2953671217
# WESTCHESTER SQ     1088643688    1005559655
# WHITEHALL S-FRY   11396362397    2837253459
# WHITLOCK AV        9411772683     916156506
# WILSON AV           683913073     614471859
# WINTHROP ST        1001913443     219222635
# WOODHAVEN BLVD     6954374353    4130885490
# WOODLAWN           1278622514     503318977
# WORLD TRADE CTR    1629807437     791499037
# YORK ST            1510509730    1322015253
# ZEREGA AV          2320431759      60070417
#
# [376 rows x 2 columns]

# %% [markdown]
# 6.Okay, so we understand what station represents. But what the heck are C/A, UNIT, and SCP? Keep in mind that in the larger stations, you might have multiple areas within one station that look like this:
#
# <img src="image.jpg" style="width: 300px;"/>
#
# Further complicating things, there are a few station names like 14TH ST that refer to more than one station location along that street.
#
# This data set is not very well documented. Welcome to the joys of real world data science!!!
#
# Read the following two links carefully to see other people's confusion and what information they have been able to gather:
#
# https://groups.google.com/forum/#!topic/mtadeveloperresources/AMVx2WUY9iI
#
# https://groups.google.com/forum/#!searchin/mtadeveloperresources/%22remote$20unit%22%7Csort:relevance/mtadeveloperresources/z8l3ZU9cY6Y/OFlHGkFAimQJ
#
# It sounds like each C/A + UNIT + SCP + STATION combo refers to a single turnstile. How many unique turnstiles are there?

# %%
print(len(mta.groupby(['C/A','UNIT','SCP','STATION'])))
# Out:
# 4695

# %% [markdown]
# 7.What data types are each of the columns?

# %%
mta.dtypes
# Out:
# C/A         object
# UNIT        object
# SCP         object
# STATION     object
# LINENAME    object
# DIVISION    object
# DATE        object
# TIME        object
# DESC        object
# ENTRIES      int64
# EXITS        int64
# dtype: object

# %% [markdown]
# 8.We can see that the exits and entries are treated as integers but the others are all treated as objects (strings). Overwrite the time column so that it is a datetime object containing the combined date and time column info (so that the times have a chronological order).

# %%
import datetime

mta.TIME = pd.to_timedelta(mta['TIME'])
mta.DATE = pd.to_datetime(mta['DATE'], format = '%m/%d/%Y')
mta['TIME'] =  mta.TIME + mta['DATE']
mta.TIME
# Out:
# 0        2017-06-10 00:00:00
# 1        2017-06-10 04:00:00
# 2        2017-06-10 08:00:00
# 3        2017-06-10 12:00:00
# 4        2017-06-10 16:00:00
# 5        2017-06-10 20:00:00
# 6        2017-06-11 00:00:00
# 7        2017-06-11 04:00:00
# 8        2017-06-11 08:00:00
# 9        2017-06-11 12:00:00
# 10       2017-06-11 16:00:00
# 11       2017-06-11 20:00:00
# 12       2017-06-12 00:00:00
# 13       2017-06-12 04:00:00
# 14       2017-06-12 08:00:00
# 15       2017-06-12 12:00:00
# 16       2017-06-12 16:00:00
# 17       2017-06-12 20:00:00
# 18       2017-06-13 00:00:00
# 19       2017-06-13 04:00:00
# 20       2017-06-13 08:00:00
# 21       2017-06-13 12:00:00
# 22       2017-06-13 16:00:00
# 23       2017-06-13 20:00:00
# 24       2017-06-14 00:00:00
# 25       2017-06-14 04:00:00
# 26       2017-06-14 08:00:00
# 27       2017-06-14 12:00:00
# 28       2017-06-14 16:00:00
# 29       2017-06-14 20:00:00
#                  ...
# 197179   2017-06-12 01:00:00
# 197180   2017-06-12 05:00:00
# 197181   2017-06-12 09:00:00
# 197182   2017-06-12 13:00:00
# 197183   2017-06-12 17:00:00
# 197184   2017-06-12 21:00:00
# 197185   2017-06-13 01:00:00
# 197186   2017-06-13 05:00:00
# 197187   2017-06-13 09:00:00
# 197188   2017-06-13 13:00:00
# 197189   2017-06-13 17:00:00
# 197190   2017-06-13 21:00:00
# 197191   2017-06-14 01:00:00
# 197192   2017-06-14 05:00:00
# 197193   2017-06-14 09:00:00
# 197194   2017-06-14 13:00:00
# 197195   2017-06-14 17:00:00
# 197196   2017-06-14 21:00:00
# 197197   2017-06-15 01:00:00
# 197198   2017-06-15 05:00:00
# 197199   2017-06-15 09:00:00
# 197200   2017-06-15 13:00:00
# 197201   2017-06-15 17:00:00
# 197202   2017-06-15 21:00:00
# 197203   2017-06-16 01:00:00
# 197204   2017-06-16 05:00:00
# 197205   2017-06-16 09:00:00
# 197206   2017-06-16 13:00:00
# 197207   2017-06-16 17:00:00
# 197208   2017-06-16 21:00:00
# Name: TIME, Length: 197209, dtype: datetime64[ns]

# %% [markdown]
# 9.What is the earliest and latest date in our dataset?

# %%
from datetime import datetime
print(min(mta.TIME))
print(max(mta.TIME))
# Out:
# 2017-06-10 00:00:00
# 2017-06-16 23:59:54

# %% [markdown]
# 10.If we wanted to only look at the 34st Street Penn Station stop on 6/12/2017, what would we type?

# %%
mta[(mta['STATION'] == '34 ST-PENN STA') & (mta['DATE'] == '2017-06-12')]
# Out:
#          C/A  UNIT       SCP         STATION LINENAME DIVISION       DATE  \
# 49612   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND 2017-06-12
# 49613   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND 2017-06-12
# 49614   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND 2017-06-12
# 49615   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND 2017-06-12
# 49616   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND 2017-06-12
# 49617   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND 2017-06-12
# 49654   N067  R012  00-00-01  34 ST-PENN STA      ACE      IND 2017-06-12
# 49655   N067  R012  00-00-01  34 ST-PENN STA      ACE      IND 2017-06-12
# 49656   N067  R012  00-00-01  34 ST-PENN STA      ACE      IND 2017-06-12
# 49657   N067  R012  00-00-01  34 ST-PENN STA      ACE      IND 2017-06-12
# 49658   N067  R012  00-00-01  34 ST-PENN STA      ACE      IND 2017-06-12
# 49659   N067  R012  00-00-01  34 ST-PENN STA      ACE      IND 2017-06-12
# 49696   N067  R012  00-00-02  34 ST-PENN STA      ACE      IND 2017-06-12
# 49697   N067  R012  00-00-02  34 ST-PENN STA      ACE      IND 2017-06-12
# 49698   N067  R012  00-00-02  34 ST-PENN STA      ACE      IND 2017-06-12
# 49699   N067  R012  00-00-02  34 ST-PENN STA      ACE      IND 2017-06-12
# 49700   N067  R012  00-00-02  34 ST-PENN STA      ACE      IND 2017-06-12
# 49701   N067  R012  00-00-02  34 ST-PENN STA      ACE      IND 2017-06-12
# 49738   N067  R012  00-00-03  34 ST-PENN STA      ACE      IND 2017-06-12
# 49739   N067  R012  00-00-03  34 ST-PENN STA      ACE      IND 2017-06-12
# 49740   N067  R012  00-00-03  34 ST-PENN STA      ACE      IND 2017-06-12
# 49741   N067  R012  00-00-03  34 ST-PENN STA      ACE      IND 2017-06-12
# 49742   N067  R012  00-00-03  34 ST-PENN STA      ACE      IND 2017-06-12
# 49781  2017-06-12 04:00:00  REGULAR    9824512   9653369
# 49782  2017-06-12 08:00:00  REGULAR    9824701   9653410
# 49783  2017-06-12 12:00:00  REGULAR    9825165   9653549
# 49784  2017-06-12 16:00:00  REGULAR    9825262   9653653
# 49785  2017-06-12 20:00:00  REGULAR    9825398   9654040
# ...                    ...      ...        ...       ...
# 130548 2017-06-12 02:00:00  REGULAR   11793909   7635796
# 130549 2017-06-12 06:00:00  REGULAR   11793920   7635819
# 130550 2017-06-12 10:00:00  REGULAR   11794110   7636243
# 130551 2017-06-12 14:00:00  REGULAR   11794495   7636464
# 130552 2017-06-12 18:00:00  REGULAR   11795211   7636726
# 130553 2017-06-12 22:00:00  REGULAR   11795846   7636833
# 130591 2017-06-12 02:00:00  REGULAR    5762606   4988972
# 130592 2017-06-12 06:00:00  REGULAR    5762616   4989000
# 130593 2017-06-12 10:00:00  REGULAR    5762815   4989626
# 130594 2017-06-12 14:00:00  REGULAR    5763208   4989941
# 130595 2017-06-12 18:00:00  REGULAR    5763846   4990260
# 130596 2017-06-12 22:00:00  REGULAR    5764370   4990430
# 130634 2017-06-12 02:00:00  REGULAR     845231   2073773
# 130635 2017-06-12 06:00:00  REGULAR     845236   2073864
# 130636 2017-06-12 10:00:00  REGULAR     845374   2075223
# 130637 2017-06-12 14:00:00  REGULAR     845619   2076008
# 130638 2017-06-12 18:00:00  REGULAR     846130   2076629
# 130639 2017-06-12 22:00:00  REGULAR     846524   2076929
# 130677 2017-06-12 02:00:00  REGULAR  100779668    668134
# 130678 2017-06-12 06:00:00  REGULAR  100779669    668144
# 130679 2017-06-12 10:00:00  REGULAR  100779669    668354
# 130680 2017-06-12 14:00:00  REGULAR  100779681    668436
# 130681 2017-06-12 18:00:00  REGULAR  100779714    668523
# 130682 2017-06-12 22:00:00  REGULAR  100779739    668545
# 130720 2017-06-12 02:00:00  REGULAR   67408984  17421651
# 130721 2017-06-12 06:00:00  REGULAR   67408990  17421670
# 130722 2017-06-12 10:00:00  REGULAR   67409078  17422388
# 130723 2017-06-12 14:00:00  REGULAR   67409230  17422857
# 130724 2017-06-12 18:00:00  REGULAR   67409465  17423289
# 130725 2017-06-12 22:00:00  REGULAR   67409651  17423548
#
# [593 rows x 11 columns]

# %% [markdown]
# 11.Create a dictionary called bigDict. It should contain a nested set of keys and values. The outermost key should be the tuple (C/A,UNIT,STATION) and its value should itself be a dictionary with the SCP as the key and a list of (TIME, EXITS) tuples as its values. The purpose of this section is to prepare data for later uses. It should take a little while to finish running.

# %%
bigDict = {}

for _,row in mta.iterrows():
    key = (row["C/A"],row["UNIT"],row["STATION"])
    sub_key = row["SCP"]
    if key in bigDict:
        if sub_key in bigDict[key]:
            bigDict[key][sub_key].append((row["TIME"],row["EXITS"]))
        else:
            bigDict[key][sub_key] = [(row["TIME"],row["EXITS"])]
    else:
        bigDict[key] = {sub_key:[(row["TIME"],row["EXITS"])]}

# %% [markdown]
# 12.As an example, use the bigDict to view all of the turnstile data located at the('A037', 'R170', '14 ST-UNION SQ') area:

# %%
bigDict[('A037', 'R170', '14 ST-UNION SQ')]
# Out:
# {'05-00-00': [(Timestamp('2017-06-10 01:00:00'), 30866),
#   (Timestamp('2017-06-10 05:00:00'), 30892),
#   (Timestamp('2017-06-10 09:00:00'), 31064),
#   (Timestamp('2017-06-10 13:00:00'), 31714),
#   (Timestamp('2017-06-10 17:00:00'), 32323),
#   (Timestamp('2017-06-10 21:00:00'), 32825),
#   (Timestamp('2017-06-11 01:00:00'), 33068),
#   (Timestamp('2017-06-11 05:00:00'), 33115),
#   (Timestamp('2017-06-11 09:00:00'), 33214),
#   (Timestamp('2017-06-11 13:00:00'), 33649),
#   (Timestamp('2017-06-11 17:00:00'), 34137),
#   (Timestamp('2017-06-11 21:00:00'), 34527),
#   (Timestamp('2017-06-12 01:00:00'), 34667),
#   (Timestamp('2017-06-12 05:00:00'), 34684),
#   (Timestamp('2017-06-12 09:00:00'), 35349),
#   (Timestamp('2017-06-12 13:00:00'), 36274),
#   (Timestamp('2017-06-12 17:00:00'), 36710),
#   (Timestamp('2017-06-12 21:00:00'), 36993),
#   (Timestamp('2017-06-13 01:00:00'), 37093),
#   (Timestamp('2017-06-13 05:00:00'), 37105),
#   (Timestamp('2017-06-13 09:00:00'), 37870),
#   (Timestamp('2017-06-13 13:00:00'), 38835),
#   (Timestamp('2017-06-13 17:00:00'), 39284),
#   (Timestamp('2017-06-13 21:00:00'), 39426),
#   (Timestamp('2017-06-14 01:00:00'), 39524),
#   (Timestamp('2017-06-14 05:00:00'), 39534),
#   (Timestamp('2017-06-14 09:00:00'), 40215),
#   (Timestamp('2017-06-14 13:00:00'), 41212),
#   (Timestamp('2017-06-14 17:00:00'), 41720),
#   (Timestamp('2017-06-14 21:00:00'), 42153),
#   (Timestamp('2017-06-15 01:00:00'), 42289),
#   (Timestamp('2017-06-15 05:00:00'), 42308),
#   (Timestamp('2017-06-15 09:00:00'), 43034),
#   (Timestamp('2017-06-15 13:00:00'), 43987),
#   (Timestamp('2017-06-15 17:00:00'), 44660),
#   (Timestamp('2017-06-15 21:00:00'), 45019),
#   (Timestamp('2017-06-16 01:00:00'), 45153),
#   (Timestamp('2017-06-16 05:00:00'), 45171),
#   (Timestamp('2017-06-16 09:00:00'), 45859),
#   (Timestamp('2017-06-16 13:00:00'), 46930),
#   (Timestamp('2017-06-16 17:00:00'), 47432),
#   (Timestamp('2017-06-16 21:00:00'), 47802)],
#  '05-00-01': [(Timestamp('2017-06-10 01:00:00'), 1039398),
#   (Timestamp('2017-06-10 05:00:00'), 1039448),
#   (Timestamp('2017-06-10 09:00:00'), 1039614),
#   (Timestamp('2017-06-10 13:00:00'), 1040090),
#   (Timestamp('2017-06-10 17:00:00'), 1040547),
#   (Timestamp('2017-06-10 21:00:00'), 1040924),
#   (Timestamp('2017-06-11 01:00:00'), 1041117),
#   (Timestamp('2017-06-11 05:00:00'), 1041167),
#   (Timestamp('2017-06-11 09:00:00'), 1041263),
#   (Timestamp('2017-06-11 13:00:00'), 1041665),
#   (Timestamp('2017-06-11 17:00:00'), 1042047),
#   (Timestamp('2017-06-11 21:00:00'), 1042319),
#   (Timestamp('2017-06-12 01:00:00'), 1042422),
#   (Timestamp('2017-06-12 05:00:00'), 1042435),
#   (Timestamp('2017-06-12 09:00:00'), 1042946),
#   (Timestamp('2017-06-12 13:00:00'), 1043634),
#   (Timestamp('2017-06-12 17:00:00'), 1043985),
#   (Timestamp('2017-06-12 21:00:00'), 1044270),
#   (Timestamp('2017-06-13 01:00:00'), 1044354),
#   (Timestamp('2017-06-13 05:00:00'), 1044373),
#   (Timestamp('2017-06-13 09:00:00'), 1044885),
#   (Timestamp('2017-06-13 13:00:00'), 1045586),
#   (Timestamp('2017-06-13 17:00:00'), 1045908),
#   (Timestamp('2017-06-13 21:00:00'), 1046021),
#   (Timestamp('2017-06-14 01:00:00'), 1046092),
#   (Timestamp('2017-06-14 05:00:00'), 1046112),
#   (Timestamp('2017-06-14 09:00:00'), 1046639),
#   (Timestamp('2017-06-14 13:00:00'), 1047350),
#   (Timestamp('2017-06-14 17:00:00'), 1047766),
#   (Timestamp('2017-06-14 21:00:00'), 1048036),
#   (Timestamp('2017-06-15 01:00:00'), 1048155),
#   (Timestamp('2017-06-15 05:00:00'), 1048172),
#   (Timestamp('2017-06-15 09:00:00'), 1048695),
#   (Timestamp('2017-06-15 13:00:00'), 1049419),
#   (Timestamp('2017-06-15 17:00:00'), 1049871),
#   (Timestamp('2017-06-15 21:00:00'), 1050204),
#   (Timestamp('2017-06-16 01:00:00'), 1050297),
#   (Timestamp('2017-06-16 05:00:00'), 1050319),
#   (Timestamp('2017-06-16 13:00:00'), 1051339),
#   (Timestamp('2017-06-16 17:00:00'), 1051758),
#   (Timestamp('2017-06-16 21:00:00'), 1052032)],
#  '05-00-02': [(Timestamp('2017-06-10 01:00:00'), 1084777),
#   (Timestamp('2017-06-10 05:00:00'), 1084800),
#   (Timestamp('2017-06-10 09:00:00'), 1084921),
#   (Timestamp('2017-06-10 13:00:00'), 1085201),
#   (Timestamp('2017-06-10 17:00:00'), 1085446),
#   (Timestamp('2017-06-10 21:00:00'), 1085615),
#   (Timestamp('2017-06-11 01:00:00'), 1085739),
#   (Timestamp('2017-06-11 05:00:00'), 1085762),
#   (Timestamp('2017-06-11 09:00:00'), 1085846),
#   (Timestamp('2017-06-11 13:00:00'), 1086056),
#   (Timestamp('2017-06-11 17:00:00'), 1086276),
#   (Timestamp('2017-06-11 21:00:00'), 1086409),
#   (Timestamp('2017-06-12 01:00:00'), 1086456),
#   (Timestamp('2017-06-12 05:00:00'), 1086469),
#   (Timestamp('2017-06-12 09:00:00'), 1086791),
#   (Timestamp('2017-06-12 13:00:00'), 1087216),
#   (Timestamp('2017-06-12 17:00:00'), 1087428),
#   (Timestamp('2017-06-12 21:00:00'), 1087615),
#   (Timestamp('2017-06-13 01:00:00'), 1087687),
#   (Timestamp('2017-06-13 05:00:00'), 1087704),
#   (Timestamp('2017-06-13 09:00:00'), 1088031),
#   (Timestamp('2017-06-13 13:00:00'), 1088460),
#   (Timestamp('2017-06-13 17:00:00'), 1088627),
#   (Timestamp('2017-06-13 21:00:00'), 1088730),
#   (Timestamp('2017-06-14 01:00:00'), 1088766),
#   (Timestamp('2017-06-14 05:00:00'), 1088780),
#   (Timestamp('2017-06-14 09:00:00'), 1089159),
#   (Timestamp('2017-06-14 13:00:00'), 1089645),
#   (Timestamp('2017-06-14 17:00:00'), 1089869),
#   (Timestamp('2017-06-14 21:00:00'), 1090044),
#   (Timestamp('2017-06-15 01:00:00'), 1090130),
#   (Timestamp('2017-06-15 05:00:00'), 1090140),
#   (Timestamp('2017-06-15 09:00:00'), 1090465),
#   (Timestamp('2017-06-15 13:00:00'), 1090836),
#   (Timestamp('2017-06-15 17:00:00'), 1091072),
#   (Timestamp('2017-06-15 21:00:00'), 1091273),
#   (Timestamp('2017-06-16 01:00:00'), 1091338),
#   (Timestamp('2017-06-16 05:00:00'), 1091355),
#   (Timestamp('2017-06-16 09:00:00'), 1091695),
#   (Timestamp('2017-06-16 13:00:00'), 1092162),
#   (Timestamp('2017-06-16 17:00:00'), 1092410),
#   (Timestamp('2017-06-16 21:00:00'), 1092586)],
#  '05-00-03': [(Timestamp('2017-06-10 01:00:00'), 3893659),
#   (Timestamp('2017-06-10 05:00:00'), 3893666),
#   (Timestamp('2017-06-10 09:00:00'), 3893697),
#   (Timestamp('2017-06-10 13:00:00'), 3893784),
#   (Timestamp('2017-06-10 17:00:00'), 3893875),
#   (Timestamp('2017-06-10 21:00:00'), 3893963),
#   (Timestamp('2017-06-11 01:00:00'), 3893996),
#   (Timestamp('2017-06-11 05:00:00'), 3894011),
#   (Timestamp('2017-06-11 09:00:00'), 3894033),
#   (Timestamp('2017-06-11 13:00:00'), 3894104),
#   (Timestamp('2017-06-11 17:00:00'), 3894188),
#   (Timestamp('2017-06-11 21:00:00'), 3894252),
#   (Timestamp('2017-06-12 01:00:00'), 3894273),
#   (Timestamp('2017-06-12 05:00:00'), 3894275),
#   (Timestamp('2017-06-12 09:00:00'), 3894364),
#   (Timestamp('2017-06-12 13:00:00'), 3894533),
#   (Timestamp('2017-06-12 17:00:00'), 3894636),
#   (Timestamp('2017-06-12 21:00:00'), 3894696),
#   (Timestamp('2017-06-13 01:00:00'), 3894737),
#   (Timestamp('2017-06-13 05:00:00'), 3894739),
#   (Timestamp('2017-06-13 09:00:00'), 3894848),
#   (Timestamp('2017-06-13 13:00:00'), 3895000),
#   (Timestamp('2017-06-13 17:00:00'), 3895071),
#   (Timestamp('2017-06-13 21:00:00'), 3895108),
#   (Timestamp('2017-06-14 01:00:00'), 3895127),
#   (Timestamp('2017-06-14 05:00:00'), 3895133),
#   (Timestamp('2017-06-14 09:00:00'), 3895217),
#   (Timestamp('2017-06-14 13:00:00'), 3895344),
#   (Timestamp('2017-06-14 17:00:00'), 3895439),
#   (Timestamp('2017-06-14 21:00:00'), 3895510),
#   (Timestamp('2017-06-15 01:00:00'), 3895547),
#   (Timestamp('2017-06-15 05:00:00'), 3895551),
#   (Timestamp('2017-06-15 09:00:00'), 3895607),
#   (Timestamp('2017-06-15 13:00:00'), 3895725),
#   (Timestamp('2017-06-15 17:00:00'), 3895816),
#   (Timestamp('2017-06-15 21:00:00'), 3895881),
#   (Timestamp('2017-06-16 01:00:00'), 3895918),
#   (Timestamp('2017-06-16 05:00:00'), 3895924),
#   (Timestamp('2017-06-16 09:00:00'), 3896022),
#   (Timestamp('2017-06-16 13:00:00'), 3896170),
#   (Timestamp('2017-06-16 17:00:00'), 3896235),
#   (Timestamp('2017-06-16 21:00:00'), 3896310)]}

# %% [markdown]
# 13.Create a function called inspection that takes in the (C/A,UNIT,STATION) tuple and SCP value and plots the exit counter data versus time.
#
# For example, the input of
# ```python
# inspection(('A037', 'R170', '14 ST-UNION SQ'), '05-00-00')
# ```
# should produce an upward trending plot.

# %%
import matplotlib.pyplot as plt
import matplotlib 

def inspection(key, sub_key):
    x = []
    y = []
    for tup in bigDict[key][sub_key]:
        x.append(tup[0])
        y.append(tup[1])
    x = matplotlib.dates.date2num(x)
    plt.plot(x,y)
    plt.show();
    
inspection(('A037', 'R170', '14 ST-UNION SQ'), '05-00-00')

# %% [markdown]
# ## Finding Data Errors
# 14.Due to bugs in MTA data, we will need to remove "incorrect" data. First, find the incorrect data by figuring out which turnstile counters aren't going strictly upwards. How many of these incorrect data values are there? Create a smaller dictionary callled "trouble" that contains the troublesome data from the bigDict.

# %%
trouble = dict()
for key in bigDict:
    for sub_key in bigDict[key]:
        num = bigDict[key][sub_key][0][1]
        for val in bigDict[key][sub_key]:
            if val[1] < num:
                if key in trouble:
                    if sub_key in trouble[key]:
                        trouble[key][sub_key].append(val)
                    else:
                        trouble[key][sub_key] = [val]           
                else:
                    trouble[key] = {sub_key: [val]}    
trouble
# Out:
# {('A011',
#   'R080',
#   '57 ST-7 AV'): {'01-00-00': [(Timestamp('2017-06-10 04:00:00'), 492547993),
#    (Timestamp('2017-06-10 08:00:00'), 492547731),
#    (Timestamp('2017-06-10 12:00:00'), 492547071),
#    (Timestamp('2017-06-10 16:00:00'), 492546458),
#    (Timestamp('2017-06-10 20:00:00'), 492545865),
#    (Timestamp('2017-06-11 00:00:00'), 492545621),
#    (Timestamp('2017-06-11 04:00:00'), 492545572),
#    (Timestamp('2017-06-11 08:00:00'), 492545434),
#    (Timestamp('2017-06-11 12:00:00'), 492544945),
#    (Timestamp('2017-06-11 16:00:00'), 492544307),
#    (Timestamp('2017-06-11 20:00:00'), 492543872),
#    (Timestamp('2017-06-12 00:00:00'), 492543686),
#    (Timestamp('2017-06-12 04:00:00'), 492543669),
#    (Timestamp('2017-06-12 08:00:00'), 492543224),
#    (Timestamp('2017-06-12 12:00:00'), 492541625),
#    (Timestamp('2017-06-12 16:00:00'), 492541005),
#    (Timestamp('2017-06-12 20:00:00'), 492540426),
#    (Timestamp('2017-06-13 00:00:00'), 492540243),
#    (Timestamp('2017-06-13 04:00:00'), 492540224),
#    (Timestamp('2017-06-13 08:00:00'), 492539621),
#    (Timestamp('2017-06-13 12:00:00'), 492537917),
#    (Timestamp('2017-06-13 16:00:00'), 492537313),
#    (Timestamp('2017-06-15 08:00:00'), 1257043042),
#    (Timestamp('2017-06-15 12:00:00'), 1257042211),
#    (Timestamp('2017-06-15 16:00:00'), 1257041852),
#    (Timestamp('2017-06-15 20:00:00'), 1257041231),
#    (Timestamp('2017-06-16 00:00:00'), 1257041038),
#    (Timestamp('2017-06-16 04:00:00'), 1257041005),
#    (Timestamp('2017-06-16 08:00:00'), 1257040831),
#    (Timestamp('2017-06-16 12:00:00'), 1257040092),
#    (Timestamp('2017-06-16 16:00:00'), 1257039764),
#    (Timestamp('2017-06-16 20:00:00'), 1257039189)]},
#  ('A043',
#   'R462',
#   'CANAL ST'): {'00-06-00': [(Timestamp('2017-06-14 17:00:00'), 162),
#    (Timestamp('2017-06-14 21:00:00'), 465),
#    (Timestamp('2017-06-15 01:00:00'), 543),
#    (Timestamp('2017-06-15 05:00:00'), 544),
#    (Timestamp('2017-06-15 09:00:00'), 735),
#    (Timestamp('2017-06-15 13:00:00'), 1244),
#    (Timestamp('2017-06-15 17:00:00'), 1619),
#    (Timestamp('2017-06-15 21:00:00'), 1877),
#    (Timestamp('2017-06-16 01:00:00'), 1940),
#    (Timestamp('2017-06-16 05:00:00'), 1941),
#    (Timestamp('2017-06-16 09:00:00'), 2138),
#    (Timestamp('2017-06-16 13:00:00'), 2640),
#    (Timestamp('2017-06-16 17:00:00'), 3065),
#    (Timestamp('2017-06-16 21:00:00'), 3310)]},
#  ('A060',
#   'R001',
#   'WHITEHALL S-FRY'): {'00-00-06': [(Timestamp('2017-06-12 17:00:00'), 2101),
#    (Timestamp('2017-06-12 21:00:00'), 2483),
#    (Timestamp('2017-06-13 01:00:00'), 2592),
#    (Timestamp('2017-06-13 05:00:00'), 2620),
#    (Timestamp('2017-06-13 09:00:00'), 3453),
#    (Timestamp('2017-06-13 13:00:00'), 4233),
#    (Timestamp('2017-06-13 17:00:00'), 4671),
#    (Timestamp('2017-06-13 21:00:00'), 5012),
#    (Timestamp('2017-06-14 01:00:00'), 5113),
#    (Timestamp('2017-06-14 05:00:00'), 5126),
#    (Timestamp('2017-06-14 09:00:00'), 6003),
#    (Timestamp('2017-06-14 13:00:00'), 6850),
#    (Timestamp('2017-06-14 17:00:00'), 7352),
#    (Timestamp('2017-06-14 21:00:00'), 7733),
#    (Timestamp('2017-06-15 01:00:00'), 7821),
#    (Timestamp('2017-06-15 05:00:00'), 7830),
#    (Timestamp('2017-06-15 09:00:00'), 8663),
#    (Timestamp('2017-06-15 13:00:00'), 9531),
#    (Timestamp('2017-06-15 17:00:00'), 10023),
#    (Timestamp('2017-06-15 21:00:00'), 10449),
#    (Timestamp('2017-06-16 01:00:00'), 10553),
#    (Timestamp('2017-06-16 05:00:00'), 10566),
#    (Timestamp('2017-06-16 09:00:00'), 11323),
#    (Timestamp('2017-06-16 13:00:00'), 12040),
#    (Timestamp('2017-06-16 17:00:00'), 12433),
#    (Timestamp('2017-06-16 21:00:00'), 12820)]},
#  ('A069',
#   'R044',
#   'CHAMBERS ST'): {'01-06-00': [(Timestamp('2017-06-16 16:00:00'), 67),
#    (Timestamp('2017-06-16 20:00:00'),
#     697)], '01-06-01': [(Timestamp('2017-06-10 04:00:00'), 1802448008),
#    (Timestamp('2017-06-10 08:00:00'), 1802447923),
#    (Timestamp('2017-06-10 12:00:00'), 1802446997),
#    (Timestamp('2017-06-10 16:00:00'), 1802445860),
#    (Timestamp('2017-06-10 20:00:00'), 1802444995),
#    (Timestamp('2017-06-11 00:00:00'), 1802444581),
#    (Timestamp('2017-06-11 04:00:00'), 1802444507),
#    (Timestamp('2017-06-11 08:00:00'), 1802444476),
#    (Timestamp('2017-06-11 12:00:00'), 1802443968),
#    (Timestamp('2017-06-11 16:00:00'), 1802443239),
#    (Timestamp('2017-06-11 20:00:00'), 1802442623),
#    (Timestamp('2017-06-12 00:00:00'), 1802442433),
#    (Timestamp('2017-06-12 04:00:00'), 1802442400),
#    (Timestamp('2017-06-12 08:00:00'), 1802442003),
#    (Timestamp('2017-06-12 12:00:00'), 1802440099),
#    (Timestamp('2017-06-12 16:00:00'), 1802439076),
#    (Timestamp('2017-06-12 20:00:00'), 1802438302),
#    (Timestamp('2017-06-13 00:00:00'), 1802438061),
#    (Timestamp('2017-06-13 04:00:00'), 1802438034),
#    (Timestamp('2017-06-13 08:00:00'), 1802437616),
#    (Timestamp('2017-06-13 12:00:00'), 1802435781),
#    (Timestamp('2017-06-13 16:00:00'), 1802434678),
#    (Timestamp('2017-06-13 20:00:00'), 1802433972),
#    (Timestamp('2017-06-14 00:00:00'), 1802433776),
#    (Timestamp('2017-06-14 04:00:00'), 1802433746),
#    (Timestamp('2017-06-14 08:00:00'), 1802433346),
#    (Timestamp('2017-06-14 12:00:00'), 1802431669),
#    (Timestamp('2017-06-14 16:00:00'), 1802430566),
#    (Timestamp('2017-06-14 20:00:00'), 1802429753),
#    (Timestamp('2017-06-15 00:00:00'), 1802429514),
#    (Timestamp('2017-06-15 04:00:00'), 1802429476),
#    (Timestamp('2017-06-15 08:00:00'), 1802429087),
#    (Timestamp('2017-06-15 12:00:00'), 1802427221),
#    (Timestamp('2017-06-15 16:00:00'), 1802426288),
#    (Timestamp('2017-06-16 12:00:00'), 1802425988),
#    (Timestamp('2017-06-16 16:00:00'), 1802424839),
#    (Timestamp('2017-06-16 20:00:00'), 1802424138)]},
#  ('B020',
#   'R263',
#   'AVENUE H'): {'00-05-00': [(Timestamp('2017-06-14 12:00:00'), 17),
#    (Timestamp('2017-06-14 16:00:00'), 87),
#    (Timestamp('2017-06-14 20:00:00'), 193),
#    (Timestamp('2017-06-15 00:00:00'), 244),
#    (Timestamp('2017-06-15 04:00:00'), 260),
#    (Timestamp('2017-06-15 08:00:00'), 289),
#    (Timestamp('2017-06-15 12:00:00'), 348),
#    (Timestamp('2017-06-15 16:00:00'), 414),
#    (Timestamp('2017-06-15 20:00:00'), 520),
#    (Timestamp('2017-06-16 00:00:00'), 578),
#    (Timestamp('2017-06-16 04:00:00'), 584),
#    (Timestamp('2017-06-16 08:00:00'), 614),
#    (Timestamp('2017-06-16 12:00:00'), 660),
#    (Timestamp('2017-06-16 16:00:00'), 736),
#    (Timestamp('2017-06-16 20:00:00'), 812)]},
#  ('B024',
#   'R211',
#   'KINGS HWY'): {'00-05-01': [(Timestamp('2017-06-12 16:00:00'), 763625369),
#    (Timestamp('2017-06-12 20:00:00'), 763625369),
#    (Timestamp('2017-06-13 00:00:00'), 763625369),
#    (Timestamp('2017-06-13 04:00:00'), 763625369),
#    (Timestamp('2017-06-13 08:00:00'), 763625369),
#    (Timestamp('2017-06-13 12:00:00'), 763625369),
#    (Timestamp('2017-06-13 16:00:00'), 763625369),
#    (Timestamp('2017-06-13 20:00:00'), 763625369),
#    (Timestamp('2017-06-14 00:00:00'), 763625369),
#    (Timestamp('2017-06-14 04:00:00'), 763625369),
#    (Timestamp('2017-06-14 08:00:00'), 763625369),
#    (Timestamp('2017-06-14 12:00:00'), 763625369),
#    (Timestamp('2017-06-14 16:00:00'), 763625369),
#    (Timestamp('2017-06-14 20:00:00'), 763625369),
#    (Timestamp('2017-06-15 00:00:00'), 763625369),
#    (Timestamp('2017-06-15 04:00:00'), 763625369),
#    (Timestamp('2017-06-15 08:00:00'), 763625369),
#    (Timestamp('2017-06-15 12:00:00'), 763625369),
#    (Timestamp('2017-06-15 16:00:00'), 763625369),
#    (Timestamp('2017-06-15 20:00:00'), 763625369),
#    (Timestamp('2017-06-16 00:00:00'), 763625369),
#    (Timestamp('2017-06-16 04:00:00'), 763625369),
#    (Timestamp('2017-06-16 08:00:00'), 763625369),
#    (Timestamp('2017-06-16 12:00:00'), 763625369),
#    (Timestamp('2017-06-16 16:00:00'), 763625369),
#    (Timestamp('2017-06-16 20:00:00'), 763625369)]},
#  ('B025',
#   'R150',
#   'AVENUE U'): {'00-00-01': [(Timestamp('2017-06-14 09:00:00'), 0)]},
#  ('C021',
#   'R212',
#   '59 ST'): {'00-00-02': [(Timestamp('2017-06-10 04:00:00'), 703393235),
#    (Timestamp('2017-06-10 08:00:00'), 703393153),
#    (Timestamp('2017-06-10 12:00:00'), 703392942),
#    (Timestamp('2017-06-10 16:00:00'), 703392673),
#    (Timestamp('2017-06-10 20:00:00'), 703392314),
#    (Timestamp('2017-06-11 00:00:00'), 703392074),
#    (Timestamp('2017-06-11 04:00:00'), 703391989),
#    (Timestamp('2017-06-11 08:00:00'), 703391941),
#    (Timestamp('2017-06-11 12:00:00'), 703391778),
#    (Timestamp('2017-06-11 16:00:00'), 703391555),
#    (Timestamp('2017-06-11 20:00:00'), 703391234),
#    (Timestamp('2017-06-12 00:00:00'), 703391004),
#    (Timestamp('2017-06-12 04:00:00'), 703390935),
#    (Timestamp('2017-06-12 08:00:00'), 703390797),
#    (Timestamp('2017-06-12 12:00:00'), 703390508),
#    (Timestamp('2017-06-12 16:00:00'), 703390172),
#    (Timestamp('2017-06-12 20:00:00'), 703389662),
#    (Timestamp('2017-06-13 00:00:00'), 703389380),
#    (Timestamp('2017-06-13 04:00:00'), 703389269),
#    (Timestamp('2017-06-13 08:00:00'), 703389132),
#    (Timestamp('2017-06-13 12:00:00'), 703388853),
#    (Timestamp('2017-06-15 09:00:00'), 1358835119),
#    (Timestamp('2017-06-15 13:00:00'), 1358834901),
#    (Timestamp('2017-06-15 17:00:00'), 1358834368),
#    (Timestamp('2017-06-15 21:00:00'), 1358833475),
#    (Timestamp('2017-06-16 01:00:00'), 1358833155),
#    (Timestamp('2017-06-16 05:00:00'), 1358833104),
#    (Timestamp('2017-06-16 09:00:00'), 1358832955),
#    (Timestamp('2017-06-16 13:00:00'), 1358832757),
#    (Timestamp('2017-06-16 17:00:00'), 1358832268),
#    (Timestamp('2017-06-16 21:00:00'), 1358831459)]},
#  ('H003',
#   'R163',
#   '6 AV'): {'01-00-02': [(Timestamp('2017-06-10 04:00:00'), 1200736371),
#    (Timestamp('2017-06-10 08:00:00'), 1200736362),
#    (Timestamp('2017-06-10 12:00:00'), 1200736330),
#    (Timestamp('2017-06-10 16:00:00'), 1200736296),
#    (Timestamp('2017-06-10 20:00:00'), 1200736262),
#    (Timestamp('2017-06-11 00:00:00'), 1200736244),
#    (Timestamp('2017-06-11 04:00:00'), 1200736236),
#    (Timestamp('2017-06-11 08:00:00'), 1200736224),
#    (Timestamp('2017-06-11 12:00:00'), 1200736191),
#    (Timestamp('2017-06-11 16:00:00'), 1200736149),
#    (Timestamp('2017-06-11 20:00:00'), 1200736129),
#    (Timestamp('2017-06-12 00:00:00'), 1200736116),
#    (Timestamp('2017-06-12 04:00:00'), 1200736111),
#    (Timestamp('2017-06-12 08:00:00'), 1200736085),
#    (Timestamp('2017-06-12 12:00:00'), 1200736048),
#    (Timestamp('2017-06-12 16:00:00'), 1200736021),
#    (Timestamp('2017-06-12 20:00:00'), 1200736001),
#    (Timestamp('2017-06-13 00:00:00'), 1200735993),
#    (Timestamp('2017-06-13 04:00:00'), 1200735989),
#    (Timestamp('2017-06-13 08:00:00'), 1200735968),
#    (Timestamp('2017-06-13 16:00:00'), 1200735882),
#    (Timestamp('2017-06-13 20:00:00'), 1200735868),
#    (Timestamp('2017-06-14 00:00:00'), 1200735861),
#    (Timestamp('2017-06-14 04:00:00'), 1200735857),
#    (Timestamp('2017-06-14 08:00:00'), 1200735828),
#    (Timestamp('2017-06-14 12:00:00'), 1200735787),
#    (Timestamp('2017-06-14 16:00:00'), 1200735750),
#    (Timestamp('2017-06-14 20:00:00'), 1200735728),
#    (Timestamp('2017-06-15 00:00:00'), 1200735705),
#    (Timestamp('2017-06-15 04:00:00'), 1200735699),
#    (Timestamp('2017-06-15 08:00:00'), 1200735673),
#    (Timestamp('2017-06-15 12:00:00'), 1200735615),
#    (Timestamp('2017-06-15 16:00:00'), 1200735589),
#    (Timestamp('2017-06-15 20:00:00'), 1200735569),
#    (Timestamp('2017-06-16 00:00:00'), 1200735542),
#    (Timestamp('2017-06-16 04:00:00'), 1200735537),
#    (Timestamp('2017-06-16 08:00:00'), 1200735510),
#    (Timestamp('2017-06-16 12:00:00'), 1200735463),
#    (Timestamp('2017-06-16 16:00:00'), 1200735433),
#    (Timestamp('2017-06-16 20:00:00'), 1200735411)]},
#  ('H009',
#   'R235',
#   'BEDFORD AV'): {'00-06-05': [(Timestamp('2017-06-14 12:00:00'), 124),
#    (Timestamp('2017-06-14 16:00:00'), 419),
#    (Timestamp('2017-06-14 20:00:00'), 1732),
#    (Timestamp('2017-06-15 00:00:00'), 2329),
#    (Timestamp('2017-06-15 04:00:00'), 2379),
#    (Timestamp('2017-06-15 08:00:00'), 2460),
#    (Timestamp('2017-06-15 12:00:00'), 2604),
#    (Timestamp('2017-06-15 16:00:00'), 2976),
#    (Timestamp('2017-06-15 20:00:00'), 4280),
#    (Timestamp('2017-06-16 00:00:00'), 4946),
#    (Timestamp('2017-06-16 04:00:00'), 5002),
#    (Timestamp('2017-06-16 08:00:00'), 5070),
#    (Timestamp('2017-06-16 12:00:00'), 5208),
#    (Timestamp('2017-06-16 16:00:00'), 5730),
#    (Timestamp('2017-06-16 20:00:00'), 6893)]},
#  ('JFK02',
#   'R535',
#   'HOWARD BCH JFK'): {'01-00-03': [(Timestamp('2017-06-11 13:00:00'), 4),
#    (Timestamp('2017-06-11 17:00:01'), 154),
#    (Timestamp('2017-06-11 21:00:00'), 271),
#    (Timestamp('2017-06-12 01:00:00'), 310),
#    (Timestamp('2017-06-12 05:00:00'), 324),
#    (Timestamp('2017-06-12 09:00:00'), 397),
#    (Timestamp('2017-06-12 13:00:00'), 488),
#    (Timestamp('2017-06-12 17:00:00'), 543),
#    (Timestamp('2017-06-12 21:00:00'), 615),
#    (Timestamp('2017-06-13 01:00:00'), 640),
#    (Timestamp('2017-06-13 05:00:00'), 663),
#    (Timestamp('2017-06-13 09:00:00'), 753),
#    (Timestamp('2017-06-13 13:00:00'), 821),
#    (Timestamp('2017-06-13 17:00:00'), 824),
#    (Timestamp('2017-06-13 21:00:00'), 845),
#    (Timestamp('2017-06-14 01:00:00'), 869),
#    (Timestamp('2017-06-14 05:00:00'), 889),
#    (Timestamp('2017-06-14 09:00:00'), 982),
#    (Timestamp('2017-06-14 13:00:00'), 1099),
#    (Timestamp('2017-06-14 17:00:00'), 1204),
#    (Timestamp('2017-06-14 21:00:00'), 1342),
#    (Timestamp('2017-06-15 01:00:00'), 1355),
#    (Timestamp('2017-06-15 05:00:00'), 1372),
#    (Timestamp('2017-06-15 09:00:00'), 1374),
#    (Timestamp('2017-06-15 13:00:00'), 1416),
#    (Timestamp('2017-06-15 17:00:00'), 1423),
#    (Timestamp('2017-06-15 21:00:00'), 1532),
#    (Timestamp('2017-06-16 01:00:00'), 1580),
#    (Timestamp('2017-06-16 05:00:00'), 1606),
#    (Timestamp('2017-06-16 09:00:00'), 1700),
#    (Timestamp('2017-06-16 13:00:00'), 1810),
#    (Timestamp('2017-06-16 17:00:00'), 2028),
#    (Timestamp('2017-06-16 21:00:00'), 2222)]},
#  ('JFK03',
#   'R536',
#   'JFK JAMAICA CT1'): {'00-03-00': [(Timestamp('2017-06-14 09:00:00'), 40),
#    (Timestamp('2017-06-14 13:00:00'), 182),
#    (Timestamp('2017-06-14 14:34:14'), 284),
#    (Timestamp('2017-06-14 17:00:00'), 447),
#    (Timestamp('2017-06-14 21:00:00'), 673),
#    (Timestamp('2017-06-15 01:00:00'), 857),
#    (Timestamp('2017-06-15 05:00:00'), 902),
#    (Timestamp('2017-06-15 09:00:00'), 1056),
#    (Timestamp('2017-06-15 13:00:00'), 1217),
#    (Timestamp('2017-06-15 17:00:00'), 1545),
#    (Timestamp('2017-06-15 21:00:00'), 1761),
#    (Timestamp('2017-06-16 01:00:00'), 1943),
#    (Timestamp('2017-06-16 05:00:00'), 1983),
#    (Timestamp('2017-06-16 09:00:00'), 2123),
#    (Timestamp('2017-06-16 13:00:00'), 2281),
#    (Timestamp('2017-06-16 17:00:00'), 2590),
#    (Timestamp('2017-06-16 21:00:00'),
#     2799)], '00-03-02': [(Timestamp('2017-06-15 17:00:00'), 28),
#    (Timestamp('2017-06-15 21:00:00'), 313),
#    (Timestamp('2017-06-16 01:00:00'), 540),
#    (Timestamp('2017-06-16 05:00:00'), 597),
#    (Timestamp('2017-06-16 09:00:00'), 798),
#    (Timestamp('2017-06-16 13:00:00'), 1051),
#    (Timestamp('2017-06-16 17:00:00'), 1373),
#    (Timestamp('2017-06-16 21:00:00'), 1641)]},
#  ('J034',
#   'R007',
#   '104 ST'): {'00-00-01': [(Timestamp('2017-06-10 04:00:00'), 1907559966),
#    (Timestamp('2017-06-10 08:00:00'), 1907559965),
#    (Timestamp('2017-06-10 12:00:00'), 1907559959),
#    (Timestamp('2017-06-10 16:00:00'), 1907559938),
#    (Timestamp('2017-06-10 20:00:00'), 1907559931),
#    (Timestamp('2017-06-11 00:00:00'), 1907559929),
#    (Timestamp('2017-06-11 04:00:00'), 1907559929),
#    (Timestamp('2017-06-11 08:00:00'), 1907559928),
#    (Timestamp('2017-06-11 12:00:00'), 1907559921),
#    (Timestamp('2017-06-11 16:00:00'), 1907559912),
#    (Timestamp('2017-06-11 20:00:00'), 1907559909),
#    (Timestamp('2017-06-12 00:00:00'), 1907559908),
#    (Timestamp('2017-06-12 04:00:00'), 1907559907),
#    (Timestamp('2017-06-12 08:00:00'), 1907559904),
#    (Timestamp('2017-06-12 12:00:00'), 1907559897),
#    (Timestamp('2017-06-12 16:00:00'), 1907559891),
#    (Timestamp('2017-06-12 20:00:00'), 1907559884),
#    (Timestamp('2017-06-13 00:00:00'), 1907559883),
#    (Timestamp('2017-06-13 04:00:00'), 1907559883),
#    (Timestamp('2017-06-13 08:00:00'), 1907559878),
#    (Timestamp('2017-06-13 12:00:00'), 1907559874),
#    (Timestamp('2017-06-13 16:00:00'), 1907559870),
#    (Timestamp('2017-06-13 20:00:00'), 1907559862),
#    (Timestamp('2017-06-14 00:00:00'), 1907559861),
#    (Timestamp('2017-06-14 04:00:00'), 1907559861),
#    (Timestamp('2017-06-14 08:00:00'), 1907559857),
#    (Timestamp('2017-06-14 12:00:00'), 1907559853),
#    (Timestamp('2017-06-14 16:00:00'), 1907559849),
#    (Timestamp('2017-06-14 20:00:00'), 1907559844),
#    (Timestamp('2017-06-15 00:00:00'), 1907559838),
#    (Timestamp('2017-06-15 04:00:00'), 1907559837),
#   'METROPOLITAN AV'): {'00-00-01': [(Timestamp('2017-06-10 04:00:00'),
#     16451625),
#    (Timestamp('2017-06-10 08:00:00'), 16451604),
#    (Timestamp('2017-06-10 12:00:00'), 16451537),
#    (Timestamp('2017-06-10 16:00:00'), 16451418),
#    (Timestamp('2017-06-10 20:00:00'), 16451332),
#    (Timestamp('2017-06-11 00:00:00'), 16451292),
#    (Timestamp('2017-06-11 04:00:00'), 16451281),
#    (Timestamp('2017-06-11 08:00:00'), 16451269),
#    (Timestamp('2017-06-11 12:00:00'), 16451208),
#    (Timestamp('2017-06-11 16:00:00'), 16451108),
#    (Timestamp('2017-06-11 20:00:00'), 16451039),
#    (Timestamp('2017-06-12 00:00:00'), 16451011),
#    (Timestamp('2017-06-12 04:00:00'), 16451006),
#    (Timestamp('2017-06-12 08:00:00'), 16450935),
#    (Timestamp('2017-06-12 12:00:00'), 16450823),
#    (Timestamp('2017-06-12 16:00:00'), 16450658),
#    (Timestamp('2017-06-12 20:00:00'), 16450299),
#    (Timestamp('2017-06-13 00:00:00'), 16450223),
#    (Timestamp('2017-06-13 04:00:00'), 16450204),
#    (Timestamp('2017-06-13 08:00:00'), 16450103),
#    (Timestamp('2017-06-13 12:00:00'), 16449966),
#    (Timestamp('2017-06-13 16:00:00'), 16449823),
#    (Timestamp('2017-06-13 20:00:00'), 16449495),
#    (Timestamp('2017-06-14 00:00:00'), 16449431),
#    (Timestamp('2017-06-14 04:00:00'), 16449418),
#    (Timestamp('2017-06-14 08:00:00'), 16449352),
#    (Timestamp('2017-06-14 12:00:00'), 16449256),
#    (Timestamp('2017-06-14 16:00:00'), 16449114),
#    (Timestamp('2017-06-14 20:00:00'), 16448763),
#    (Timestamp('2017-06-15 00:00:00'), 16448655),
#    (Timestamp('2017-06-15 04:00:00'), 16448634),
#    (Timestamp('2017-06-15 08:00:00'), 16448546),
#    (Timestamp('2017-06-15 12:00:00'), 16448410),
#    (Timestamp('2017-06-15 16:00:00'), 16448255),
#    (Timestamp('2017-06-15 20:00:00'), 16447949),
#    (Timestamp('2017-06-16 00:00:00'), 16447844),
#    (Timestamp('2017-06-16 04:00:00'), 16447825),
#    (Timestamp('2017-06-16 08:00:00'), 16447739),
#    (Timestamp('2017-06-16 12:00:00'), 16447632),
#    (Timestamp('2017-06-16 16:00:00'), 16447465),
#    (Timestamp('2017-06-16 20:00:00'), 16447161)]},
#  ('N016A',
#   'R296',
#   '163 ST-AMSTERDM'): {'00-00-01': [(Timestamp('2017-06-10 05:00:00'),
#     664232020),
#    (Timestamp('2017-06-10 09:00:00'), 664232013),
#    (Timestamp('2017-06-10 13:00:00'), 664231981),
#    (Timestamp('2017-06-10 17:00:00'), 664231934),
#    (Timestamp('2017-06-10 21:00:00'), 664231864),
#    (Timestamp('2017-06-11 01:00:00'), 664231845),
#    (Timestamp('2017-06-11 05:00:00'), 664231832),
#    (Timestamp('2017-06-11 09:00:00'), 664231828),
#    (Timestamp('2017-06-11 13:00:00'), 664231818),
#    (Timestamp('2017-06-11 17:00:00'), 664231806),
#    (Timestamp('2017-06-13 17:00:00'), 1626408678),
#    (Timestamp('2017-06-13 21:00:00'), 1626408227),
#    (Timestamp('2017-06-14 01:00:00'), 1626407930),
#    (Timestamp('2017-06-14 05:00:00'), 1626407885),
#    (Timestamp('2017-06-14 09:00:00'), 1626407698),
#    (Timestamp('2017-06-14 13:00:00'), 1626407432),
#    (Timestamp('2017-06-14 17:00:00'), 1626407085),
#    (Timestamp('2017-06-14 21:00:00'), 1626406578),
#    (Timestamp('2017-06-15 01:00:00'), 1626406299),
#    (Timestamp('2017-06-15 05:00:00'), 1626406263),
#    (Timestamp('2017-06-15 09:00:00'), 1626406092),
#    (Timestamp('2017-06-15 13:00:00'), 1626405819),
#    (Timestamp('2017-06-15 17:00:00'), 1626405456),
#    (Timestamp('2017-06-15 21:00:00'), 1626404984),
#    (Timestamp('2017-06-16 01:00:00'), 1626404709),
#    (Timestamp('2017-06-16 05:00:00'), 1626404659),
#    (Timestamp('2017-06-16 09:00:00'), 1626404469),
#    (Timestamp('2017-06-16 13:00:00'), 1626404192),
#    (Timestamp('2017-06-16 17:00:00'), 1626403810),
#    (Timestamp('2017-06-16 21:00:00'), 1626403337)]},
#  ('N062',
#   'R011',
#   '42 ST-PORT AUTH'): {'01-00-01': [(Timestamp('2017-06-10 04:00:00'),
#     1691831823),
#    (Timestamp('2017-06-10 08:00:00'), 1691831726),
#    (Timestamp('2017-06-10 12:00:00'), 1691831415),
#    (Timestamp('2017-06-10 16:00:00'), 1691830937),
#    (Timestamp('2017-06-10 20:00:00'), 1691830450),
#    (Timestamp('2017-06-11 00:00:00'), 1691830138),
#    (Timestamp('2017-06-11 04:00:00'), 1691830112),
#    (Timestamp('2017-06-11 08:00:00'), 1691830052),
#    (Timestamp('2017-06-11 12:00:00'), 1691829800),
#    (Timestamp('2017-06-11 16:00:00'), 1691829389),
#    (Timestamp('2017-06-11 20:00:00'), 1691828983),
#    (Timestamp('2017-06-12 00:00:00'), 1691828711),
#    (Timestamp('2017-06-12 04:00:00'), 1691828693),
#    (Timestamp('2017-06-12 08:00:00'), 1691828514),
#    (Timestamp('2017-06-12 12:00:00'), 1691828220),
#    (Timestamp('2017-06-12 16:00:00'), 1691827712),
#    (Timestamp('2017-06-12 20:00:00'), 1691826210),
#    (Timestamp('2017-06-13 00:00:00'), 1691825863),
#    (Timestamp('2017-06-13 04:00:00'), 1691825833),
#    (Timestamp('2017-06-13 08:00:00'), 1691825707),
#    (Timestamp('2017-06-13 12:00:00'), 1691825418),
#    (Timestamp('2017-06-13 16:00:00'), 1691824902),
#    (Timestamp('2017-06-13 20:00:00'), 1691823369),
#    (Timestamp('2017-06-14 00:00:00'), 1691822949),
#    (Timestamp('2017-06-14 04:00:00'), 1691822921),
#    (Timestamp('2017-06-14 08:00:00'), 1691822803),
#    (Timestamp('2017-06-14 09:02:26'), 1691822733),
#    (Timestamp('2017-06-14 12:00:00'), 1691822505),
#    (Timestamp('2017-06-14 16:00:00'), 1691821977),
#    (Timestamp('2017-06-14 20:00:00'), 1691820429),
#    (Timestamp('2017-06-16 01:00:00'), 40),
#    (Timestamp('2017-06-16 05:00:00'), 43),
#    (Timestamp('2017-06-16 09:00:00'), 105),
#    (Timestamp('2017-06-16 13:00:00'), 174),
#    (Timestamp('2017-06-16 17:00:00'), 220),
#    (Timestamp('2017-06-16 21:00:00'), 236)]},
#  ('N327',
#   'R254',
#   'GRAND-NEWTOWN'): {'00-06-01': [(Timestamp('2017-06-10 04:00:00'),
#     964176464),
#    (Timestamp('2017-06-10 08:00:00'), 964176454),
#    (Timestamp('2017-06-10 12:00:00'), 964176402),
#    (Timestamp('2017-06-10 16:00:00'), 964176342),
#    (Timestamp('2017-06-10 20:00:00'), 964176277),
#    (Timestamp('2017-06-11 00:00:00'), 964176238),
#    (Timestamp('2017-06-11 04:00:00'), 964176232),
#    (Timestamp('2017-06-11 08:00:00'), 964176225),
#    (Timestamp('2017-06-11 12:00:00'), 964176185),
#    (Timestamp('2017-06-11 16:00:00'), 964176109),
#    (Timestamp('2017-06-11 20:00:00'), 964176054),
#    (Timestamp('2017-06-12 00:00:00'), 964176027),
#    (Timestamp('2017-06-12 04:00:00'), 964176022),
#    (Timestamp('2017-06-12 08:00:00'), 964175992),
#    (Timestamp('2017-06-12 12:00:00'), 964175947),
#    (Timestamp('2017-06-12 16:00:00'), 964175864),
#    (Timestamp('2017-06-12 20:00:00'), 964175651),
#    (Timestamp('2017-06-13 00:00:00'), 964175596),
#    (Timestamp('2017-06-13 04:00:00'), 964175592),
#    (Timestamp('2017-06-13 08:00:00'), 964175582),
#    (Timestamp('2017-06-13 12:00:00'), 964175549),
#    (Timestamp('2017-06-13 16:00:00'), 964175463),
#    (Timestamp('2017-06-13 20:00:00'), 964175262),
#    (Timestamp('2017-06-14 00:00:00'), 964175203),
#    (Timestamp('2017-06-14 04:00:00'), 964175197),
#    (Timestamp('2017-06-14 08:00:00'), 964175186),
#    (Timestamp('2017-06-14 12:00:00'), 964175141),
#    (Timestamp('2017-06-14 16:00:00'), 964175049),
#    (Timestamp('2017-06-14 20:00:00'), 964174874),
#    (Timestamp('2017-06-15 00:00:00'), 964174796),
#    (Timestamp('2017-06-15 04:00:00'), 964174781),
#    (Timestamp('2017-06-15 08:00:00'), 964174775),
#    (Timestamp('2017-06-15 12:00:00'), 964174724),
#    (Timestamp('2017-06-15 16:00:00'), 964174643),
#    (Timestamp('2017-06-15 20:00:00'), 964174475),
#    (Timestamp('2017-06-16 00:00:00'), 964174392),
#    (Timestamp('2017-06-16 04:00:00'), 964174385),
#    (Timestamp('2017-06-16 08:00:00'), 964174379),
#    (Timestamp('2017-06-16 12:00:00'), 964174338),
#    (Timestamp('2017-06-16 16:00:00'), 964174264),
#    (Timestamp('2017-06-16 20:00:00'), 964174091)]},
#  ('N334B',
#   'R341',
#   '75 AV'): {'00-06-02': [(Timestamp('2017-06-10 04:00:00'), 942640998),
#    (Timestamp('2017-06-10 08:00:00'), 942640985),
#    (Timestamp('2017-06-10 12:00:00'), 942640924),
#    (Timestamp('2017-06-10 16:00:00'), 942640856),
#    (Timestamp('2017-06-10 20:00:00'), 942640773),
#    (Timestamp('2017-06-11 00:00:00'), 942640708),
#    (Timestamp('2017-06-11 04:00:00'), 942640697),
#    (Timestamp('2017-06-11 08:00:00'), 942640681),
#    (Timestamp('2017-06-11 12:00:00'), 942640652),
#    (Timestamp('2017-06-11 16:00:00'), 942640584),
#    (Timestamp('2017-06-11 20:00:00'), 942640498),
#    (Timestamp('2017-06-12 00:00:00'), 942640435),
#    (Timestamp('2017-06-12 04:00:00'), 942640427),
#    (Timestamp('2017-06-12 08:00:00'), 942640413),
#    (Timestamp('2017-06-12 12:00:00'), 942640359),
#    (Timestamp('2017-06-12 16:00:00'), 942640288),
#    (Timestamp('2017-06-12 20:00:00'), 942640124),
#    (Timestamp('2017-06-13 00:00:00'), 942640036),
#    (Timestamp('2017-06-13 04:00:00'), 942640027),
#    (Timestamp('2017-06-13 08:00:00'), 942640012),
#    (Timestamp('2017-06-13 12:00:00'), 942639952),
#    (Timestamp('2017-06-13 16:00:00'), 942639872),
#    (Timestamp('2017-06-13 20:00:00'), 942639700),
#    (Timestamp('2017-06-14 00:00:00'), 942639610),
#    (Timestamp('2017-06-14 04:00:00'), 942639595),
#    (Timestamp('2017-06-14 08:00:00'), 942639588),
#    (Timestamp('2017-06-14 12:00:00'), 942639531),
#    (Timestamp('2017-06-14 16:00:00'), 942639474),
#    (Timestamp('2017-06-14 20:00:00'), 942639317),
#    (Timestamp('2017-06-15 00:00:00'), 942639214),
#    (Timestamp('2017-06-15 04:00:00'), 942639198),
#    (Timestamp('2017-06-15 08:00:00'), 942639183),
#    (Timestamp('2017-06-15 12:00:00'), 942639117),
#    (Timestamp('2017-06-15 16:00:00'), 942639054),
#    (Timestamp('2017-06-15 20:00:00'), 942638880),
#    (Timestamp('2017-06-16 00:00:00'), 942638774),
#    (Timestamp('2017-06-16 04:00:00'), 942638764),
#    (Timestamp('2017-06-16 08:00:00'), 942638752),
#    (Timestamp('2017-06-16 12:00:00'), 942638690),
#    (Timestamp('2017-06-16 16:00:00'), 942638606),
#    (Timestamp('2017-06-16 20:00:00'), 942638472)]},
#  ('N501',
#   'R020',
#   '47-50 STS ROCK'): {'01-06-00': [(Timestamp('2017-06-11 12:00:00'), 0),
#    (Timestamp('2017-06-11 16:00:00'), 8),
#    (Timestamp('2017-06-11 20:00:00'), 15),
#    (Timestamp('2017-06-12 00:00:00'), 24),
#    (Timestamp('2017-06-12 04:00:00'), 26),
#    (Timestamp('2017-06-12 08:00:00'), 40),
#    (Timestamp('2017-06-12 12:00:00'), 144),
#    (Timestamp('2017-06-12 16:00:00'), 171),
#    (Timestamp('2017-06-12 20:00:00'), 223),
#    (Timestamp('2017-06-13 00:00:00'), 223),
#    (Timestamp('2017-06-13 04:00:00'), 223),
#    (Timestamp('2017-06-13 08:00:00'), 235),
#    (Timestamp('2017-06-13 12:00:00'), 370),
#    (Timestamp('2017-06-13 16:00:00'), 382),
#    (Timestamp('2017-06-13 20:00:00'), 431),
#    (Timestamp('2017-06-14 00:00:00'), 438),
#    (Timestamp('2017-06-16 13:00:00'), 1207699538),
#    (Timestamp('2017-06-16 17:00:00'), 1207698876),
#    (Timestamp('2017-06-16 21:00:00'), 1207698526)]},
#  ('R245',
#   'R051',
#   '59 ST'): {'00-03-02': [(Timestamp('2017-06-10 04:00:00'), 736762048),
#    (Timestamp('2017-06-10 08:00:00'), 736762001),
#    (Timestamp('2017-06-10 12:00:00'), 736761778),
#    (Timestamp('2017-06-10 16:00:00'), 736761448),
#    (Timestamp('2017-06-10 20:00:00'), 736761168),
#    (Timestamp('2017-06-11 00:00:00'), 736761061),
#    (Timestamp('2017-06-11 04:00:00'), 736761036),
#    (Timestamp('2017-06-11 08:00:00'), 736761009),
#    (Timestamp('2017-06-11 12:00:00'), 736760818),
#    (Timestamp('2017-06-11 16:00:00'), 736760542),
#    (Timestamp('2017-06-11 20:00:00'), 736760316),
#    (Timestamp('2017-06-12 00:00:00'), 736760207),
#    (Timestamp('2017-06-12 04:00:00'), 736760184),
#    (Timestamp('2017-06-12 08:00:00'), 736759992),
#    (Timestamp('2017-06-12 12:00:00'), 736759439),
#    (Timestamp('2017-06-12 16:00:00'), 736759035),
#    (Timestamp('2017-06-12 20:00:00'), 736758478),
#    (Timestamp('2017-06-13 00:00:00'), 736758362),
#    (Timestamp('2017-06-13 04:00:00'), 736758343),
#    (Timestamp('2017-06-13 08:00:00'), 736758133),
#    (Timestamp('2017-06-13 12:00:00'), 736757554),
#    (Timestamp('2017-06-13 16:00:00'), 736757123),
#    (Timestamp('2017-06-13 20:00:00'), 736756529),
#    (Timestamp('2017-06-14 00:00:00'), 736756361),
#    (Timestamp('2017-06-14 04:00:00'), 736756339),
#    (Timestamp('2017-06-14 08:00:00'), 736756136),
#    (Timestamp('2017-06-14 12:00:00'), 736755509),
#    (Timestamp('2017-06-14 16:00:00'), 736754879),
#    (Timestamp('2017-06-14 20:00:00'), 736754246),
#    (Timestamp('2017-06-15 00:00:00'), 736754078),
#    (Timestamp('2017-06-15 04:00:00'), 736754058),
#    (Timestamp('2017-06-15 08:00:00'), 736754046),
#    (Timestamp('2017-06-15 12:00:00'), 736753663),
#    (Timestamp('2017-06-15 16:00:00'), 736753212),
#    (Timestamp('2017-06-15 20:00:00'), 736752614),
#    (Timestamp('2017-06-16 00:00:00'), 736752410),
#    (Timestamp('2017-06-16 04:00:00'), 736752385),
#    (Timestamp('2017-06-16 08:00:00'), 736752205),
#    (Timestamp('2017-06-16 12:00:00'), 736751688),
#    (Timestamp('2017-06-16 16:00:00'), 736751269),
#    (Timestamp('2017-06-16 20:00:00'), 736750777)]},
#  ('R249',
#   'R179',
#   '86 ST'): {'01-00-04': [(Timestamp('2017-06-10 04:00:00'), 1876646324),
#    (Timestamp('2017-06-10 08:00:00'), 1876646301),
#    (Timestamp('2017-06-10 12:00:00'), 1876646192),
#    (Timestamp('2017-06-10 16:00:00'), 1876646092),
#    (Timestamp('2017-06-10 20:00:00'), 1876645971),
#    (Timestamp('2017-06-11 00:00:00'), 1876645933),
#    (Timestamp('2017-06-11 04:00:00'), 1876645921),
#    (Timestamp('2017-06-15 05:00:00'), 1314629731),
#    (Timestamp('2017-06-15 09:00:00'), 1314629653),
#    (Timestamp('2017-06-15 13:00:00'), 1314629542),
#    (Timestamp('2017-06-15 17:00:00'), 1314629373),
#    (Timestamp('2017-06-15 21:00:00'), 1314629005),
#    (Timestamp('2017-06-16 01:00:00'), 1314628871),
#    (Timestamp('2017-06-16 05:00:00'), 1314628848),
#    (Timestamp('2017-06-16 09:00:00'), 1314628783),
#    (Timestamp('2017-06-16 13:00:00'), 1314628664),
#    (Timestamp('2017-06-16 17:00:00'), 1314628470),
#    (Timestamp('2017-06-16 21:00:00'), 1314628178)]}}

# %% [markdown]
# 15.Using the troublesome dictionary and your inspection plotting function, plot all of the troublesome data. There are several different types of errors. What do you think is causing each type?

# %%
for key in trouble:
    for sub_key in trouble[key]:
        inspection(key, sub_key)

# %% [markdown]
# ## Data Cleanup
# There are three types of mistakes: decreasing, garbage values, and turnstile resets.

# %% [markdown]
# #### Mistake Type I: Monotone but Decreasing - To fix this, we reflect the data.
#
# 16.Run the cell below to fix it:

# %%
def isMonotoneDecrease(tup):
    '''Input: Tuple of (Station,SCP). 
    Output: True if this SCP has monotone property, but decreasing, False otherwise.'''
    n = len(bigDict[tup[0]][tup[1]])
    for i in range(n-1):
        if(bigDict[tup[0]][tup[1]][i+1][1]>bigDict[tup[0]][tup[1]][i][1]):
            return False
    return True

def fixMonotoneDecrease(tup):
    '''reflects the data to fix it'''
    n = len(bigDict[tup[0]][tup[1]])
    for i in range(n):
        bigDict[tup[0]][tup[1]][i] = (bigDict[tup[0]][tup[1]][i][0],(-1)*bigDict[tup[0]][tup[1]][i][1])
    

monotoneDecreaseList = []

for k in trouble:
    for l in trouble[k]:
        print(k[2], l)
        
        
for k in trouble:
    for l in trouble[k]:
        if(isMonotoneDecrease((k[2], l))):
            monotoneDecreaseList.append(k)
            
print("Total Monotone Decrease:",len(monotoneDecreaseList))
for k in monotoneDecreaseList:
    fixMonotoneDecrease(k)
print("Problem Fixed!")

for k in trouble:
    if(isMonotoneDecrease(k)):
        monotoneDecreaseList.append(k)
print("Total Monotone Decrease:",len(monotoneDecreaseList))
for k in monotoneDecreaseList:
    inspection(k[0], k[1])
# Out:
# 57 ST-7 AV 01-00-00
# 57 ST-7 AV 01-00-03
# CANAL ST 00-06-00
# WHITEHALL S-FRY 00-00-06
# CHAMBERS ST 01-06-00
# CHAMBERS ST 01-06-01
# AVENUE H 00-05-00
# KINGS HWY 00-05-01
# AVENUE U 00-00-01
# 59 ST 00-00-02
# 18 AV 00-00-02
# 6 AV 01-00-02
# BEDFORD AV 00-06-05
# HOWARD BCH JFK 01-00-03
# JFK JAMAICA CT1 00-03-00
# JFK JAMAICA CT1 00-03-02
# 104 ST 00-00-01
# 104 ST 00-00-02
# METROPOLITAN AV 00-00-01
# 163 ST-AMSTERDM 00-00-01
# 116 ST 01-00-02
# 42 ST-PORT AUTH 01-00-01
# 14 ST 01-03-00
# HIGH ST 00-00-01
# CLINTON-WASH AV 00-06-01
# 111 ST 01-06-01
# 161/YANKEE STAD 00-00-01
# 36 ST 01-06-01
# GRAND-NEWTOWN 00-06-01
# 75 AV 00-06-02
# 47-50 STS ROCK 01-06-00
# 34 ST-HERALD SQ 00-05-02
# GRAND ST 00-00-02
# 7 AV 00-00-01
# AVENUE I 00-00-00
# LEXINGTON AV/63 00-00-01
# JAMAICA CENTER 00-00-05
# NEWARK HW BMEBE 00-00-05
# NEWARK HW BMEBE 00-00-07
# NEWARK HW BMEBE 00-01-02
# JOURNAL SQUARE 00-01-00
# CITY / BUS 00-02-00
# CITY / BUS 00-02-01
# 14TH STREET 00-00-03
# 14TH STREET 00-04-00
# LACKAWANNA 01-00-03
# NEWARK BM BW 01-02-03
# 14 ST 00-00-00
# 72 ST 01-06-02
# FULTON ST 02-05-01
# 23 ST 00-00-00
# GRD CNTRL-42 ST 00-00-01
# GRD CNTRL-42 ST 00-00-00
# 59 ST 00-03-02
# 86 ST 01-00-04
# 174 ST 00-00-02
# FRANKLIN AV 00-00-00
# FLATBUSH AV-B.C 01-00-01
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-137-fa748d5a1787> in <module>()
#      24 for k in trouble:
#      25     for l in trouble[k]:
# ---> 26         if(isMonotoneDecrease((k[2], l))):
#      27             monotoneDecreaseList.append(k)
#      28
#
# <ipython-input-137-fa748d5a1787> in isMonotoneDecrease(tup)
#       2     '''Input: Tuple of (Station,SCP).
#       3     Output: True if this SCP has monotone property, but decreasing, False otherwise.'''
# ----> 4     n = len(bigDict[tup[0]][tup[1]])
#       5     for i in range(n-1):
#       6         if(bigDict[tup[0]][tup[1]][i+1][1]>bigDict[tup[0]][tup[1]][i][1]):
#
# KeyError: '57 ST-7 AV'

# %% [markdown]
# #### Mistake Type II: Garbage Value - To fix this, remove the garbage value
#
# 17.Run the cell below to fix it:

# %%
def garbageEliminator(tup):
    '''removes nonsensical isolated points'''
    n = len(bigDict[tup[0]][tup[1]])
    toDel = []
    for i in range(1,n-1):
        if((bigDict[tup[0]][tup[1]][i-1][1]>bigDict[tup[0]][tup[1]][i+1][1])):
            continue
        if((bigDict[tup[0]][tup[1]][i-1][1]<=bigDict[tup[0]][tup[1]][i][1]) and (bigDict[tup[0]][tup[1]][i][1]<=bigDict[tup[0]][tup[1]][i+1][1])):
            continue
        toDel.append(bigDict[tup[0]][tup[1]][i])
    #Deletion Process
    if(len(toDel)==0):
        return 0
    for k in toDel:
        bigDict[tup[0]][tup[1]].remove(k)
    return 1


#Driver
cnt = 0
healList = []
for k in trouble:
    if(garbageEliminator(k)):
        healList.append(k)
print("Garbage Removed:",len(healList))
for k in healList:
    inspection(k[0], k[1])

# %% [markdown]
# #### Mistake Type III: Turnstile Reset - To fix this, shift the data upwards.
#
# 18.Run the cell below to fix it:

# %%
def dealingWithReset(tup):
    '''for counters that are reset, we fix the data by shifting it upwards'''
    sta = tup[0]
    tsl = tup[1]
    n = len(bigDict[sta][tsl])
    #Detecting Part
    resetPoint = [] # it means (i,i+1) is reset
    resetSet = []
    for i in range(1,n-2):
        if(bigDict[sta][tsl][i][1]<=bigDict[sta][tsl][i+1][1]):
            continue #We don't need to change this one
        resetPoint.append(i)
    #Fixing Part
    resetSet = set(resetPoint)
    cumulative = 0
    for i in range(n-2):
        if(i not in resetSet):
            bigDict[sta][tsl][i] = (bigDict[sta][tsl][i][0],bigDict[sta][tsl][i][1]+cumulative)
            continue
        #Problem
        expected = (bigDict[sta][tsl][i][1]-bigDict[sta][tsl][i-1][1])+ (bigDict[sta][tsl][i+2][1]-bigDict[sta][tsl][i+1][1])
        expected = int(expected/2)
        shift = (bigDict[sta][tsl][i][1]+expected)-bigDict[sta][tsl][i+1][1]
        cumulative = shift
    for i in range(n-2,n):
        bigDict[sta][tsl][i] = (bigDict[sta][tsl][i][0],bigDict[sta][tsl][i][1]+cumulative)
    #Done!
    
#Test Usage
inspection(('JFK03', 'R536', 'JFK JAMAICA CT1'), '00-03-00')
dealingWithReset((('JFK03', 'R536', 'JFK JAMAICA CT1'), '00-03-00'))
print("Cleaned")
inspection(('JFK03', 'R536', 'JFK JAMAICA CT1'), '00-03-00')

# %% [markdown]
# ## Overall Cleaning Process
# 19.This next cell does all of the previous cleanup in one cell. Run the cell below:

# %%
toClean = {}
for st,stv in bigDict.items():
    for scp,lst in stv.items():
        #Cleaning in Each LIST of turnstile
        toDel = []
        n = len(lst)
        lst.sort()
        for i in range(1,n-1):
            if(lst[i-1][1]<=lst[i][1] and lst[i][1]<=lst[i+1][1]): #What we expected Data to be (Non-Decreasing)
                continue

            key = (st,scp)
            toClean[key] = trouble.get(key,0)+1
            
for k in toClean.keys():
    if(isMonotoneDecrease(k)):
        fixMonotoneDecrease(k)
    garbageEliminator(k)
    dealingWithReset(k)
    inspection(k[0], k[1])

# %% [markdown]
# 20.Which troublesome stations are left?

# %%
trouble = {}
for st,stv in bigDict.items():
    for scp,lst in stv.items():
        #Cleaning in Each LIST of turnstile
        toDel = []
        n = len(lst)
        lst.sort()
        for i in range(1,n-1):
            if(lst[i-1][1]<=lst[i][1] and lst[i][1]<=lst[i+1][1]): #What we expected Data to be (Non-Decreasing)
                continue
                
            key = (st,scp)
            trouble[key] = trouble.get(key,0)+1
print("Trouble List: ",len(trouble.keys()))
for k,v in trouble.items():
    print(k,v)
# Out:
# Trouble List:  2
# (('PTH11', 'R545', '14TH STREET'), '00-00-03') 3
# (('R240', 'R047', 'GRD CNTRL-42 ST'), '00-00-01') 1

# %% [markdown]
# 21.Delete these two keys from bigDict manually:

# %%
del bigDict[('PTH11', 'R545', '14TH STREET')]['00-00-03']
del bigDict[('R240', 'R047', 'GRD CNTRL-42 ST')]['00-00-01']

# %% [markdown]
# 22.The data is now all cleaned, so let's save it so that we don't have to run all of the above code every time. Use the pickle package to save bigDict as an "MTAdict.pkl" file.

# %%
import pickle
pickle.dump(bigDict, open("MTAdict.pkl", 'wb'))

# %% [markdown]
# # --At this point, the data is ready to use and so we are ready for data analysis.--
# 23.Let's read the cleaned data file back in and save it as bigDict.

# %%
bigDict = pickle.load(open("MTAdict.pkl", 'rb'))

# %% [markdown]
# 24.Create a function called turnstileRiders that takes in a single turnstile's date/exit info and a start and endtime (in datetime format) and returns the number of riders through that turnstile within that time period. As an extension, you may want to use a linear approximation in the case of incomplete information.
#
# For instance, the input
# ```python
# t1 = dt.strptime("2017-06-12 00:00:00","%Y-%m-%d %H:%M:%S")
# t2 = dt.strptime("2017-06-13 00:00:00","%Y-%m-%d %H:%M:%S")
# turnstileRiders(bigDict[('R204', 'R043', 'WALL ST')]["02-00-00"],t1,t2)
# ```
#
# should output 1419 riders.

# %%
from datetime import datetime as dt

def turnstileRiders(date_exit, start_time, end_time):
    total = 0
    exitlist = []
    for date, exit in date_exit:
        if date >= start_time and date <= end_time:
            exitlist.append(exit)
    try:
        return (max(exitlist)-min(exitlist))
    except:
        return 0
        
t1 = datetime.strptime("2017-06-12 00:00:00","%Y-%m-%d %H:%M:%S")
t2 = datetime.strptime("2017-06-13 00:00:00","%Y-%m-%d %H:%M:%S")
turnstileRiders(bigDict[('R204', 'R043', 'WALL ST')]["02-00-00"],t1,t2)
# Out:
# 1388

# %% [markdown]
# 25.Create a function called stationRiders that calls the turnstileRiders function for each turnstile in a  (C/A,UNIT,STATION) station area and tallies all of the riders through that area between two times.
#
# For example, an input of
# ```python
# getStationRangeRider(bigDict[('R204', 'R043', 'WALL ST')],dt(2017,6,12,0,0,0),dt(2017,6,13,0,0,0))
# ```
# should output 9507 riders.

# %%
def stationRiders(station, start_time, end_time):
    total = 0
    for scp in station:
        total += turnstileRiders(station[scp],start_time,end_time)
    return total
stationRiders(bigDict[('R204', 'R043', 'WALL ST')],dt(2017,6,12,0,0,0),dt(2017,6,13,0,0,0))
# Out:
# 9397

# %% [markdown]
# 26.There are still several station areas within a station. Make a plot of the day of the week versus the number of total station rider exits for the ENTIRE Wall St station.

# %%
import matplotlib.pyplot as plt
import matplotlib 

x = []
y = []

for i in range(7):
    start_time = dt(2017,6,10+i,0,0,0)
    end_time = dt(2017,6,11+i,0,0,0)
    x.append(start_time)
    y.append(stationRiders(bigDict[('R204', 'R043', 'WALL ST')],start_time,end_time))

plt.plot(x,y)
plt.show();

# %% [markdown]
# 27.Sort by busiest station areas during 6/12 midnight - 6/13 midnight in descending order by creating a list of sorted tuples:

# %%
start_time = dt(2017,6,12,0,0,0)
end_time = dt(2017,6,17,0,0,0)

x = []
y = []
y_val = []
i = 0
for ele in bigDict:
    y_val.append((stationRiders(bigDict[ele],start_time,end_time),ele,i))
    i+=1

y_val.sort(reverse=True)
top_ten = y_val[:10]

print(top_ten)
j = 0
for ele in top_ten:
    x.append(j)
    j+=1
    y.append(ele[0])
plt.plot(x,y)
plt.show()
# Out:
# [(278970, ('R238', 'R046', 'GRD CNTRL-42 ST'), 557), (269824, ('PTH22', 'R540', 'PATH NEW WTC'), 448), (191494, ('R249', 'R179', '86 ST'), 571), (184920, ('R240', 'R047', 'GRD CNTRL-42 ST'), 559), (152336, ('H009', 'R235', 'BEDFORD AV'), 118), (149083, ('R533', 'R055', 'FLUSHING-MAIN'), 683), (142597, ('A025', 'R023', '34 ST-HERALD SQ'), 11), (142450, ('R138', 'R293', '34 ST-PENN STA'), 480), (142254, ('N500', 'R020', '47-50 STS ROCK'), 361), (140941, ('N506', 'R022', '34 ST-HERALD SQ'), 368)]

# %% [markdown]
# 28.Make a dictionary called total_dict that contains the station name as its key and the total number of riders through all of its station areas between 6/12-6/13 as its value. Then create a sorted list of tuples to view the busiest stations on that day.

# %%
### This code prints the top ten for each weekday
# end_time = dt(2017,6,13,0,0,0)
for i in range(12,17):
    station_list = []
    for j in range(20):
        start_time = dt(2017,6,i,j,0,0)
        end_time = dt(2017,6,i,j+4,0,0)
        total_dict = dict()
        for key in bigDict:
            station = key[2]
            if station not in total_dict:
                total_dict[station] = stationRiders(bigDict[key],start_time,end_time)
            else:
                total_dict[station] += stationRiders(bigDict[key],start_time,end_time)
        for station, num in total_dict.items():
            station_list.append((num, station, start_time.hour))
    station_list.sort(reverse=True)
    print(station_list[:10])
# Out:
# [(40928, '34 ST-PENN STA', 16), (37677, '34 ST-HERALD SQ', 8), (36186, 'TIMES SQ-42 ST', 8), (35638, '47-50 STS ROCK', 8), (31241, '34 ST-HERALD SQ', 16), (26889, 'GRD CNTRL-42 ST', 8), (25658, '14 ST-UNION SQ', 9), (24753, 'LEXINGTON AV/53', 8), (23712, '34 ST-PENN STA', 8), (23052, '42 ST-PORT AUTH', 16)]
# [(43051, '34 ST-PENN STA', 16), (40329, '34 ST-HERALD SQ', 8), (37679, '47-50 STS ROCK', 8), (36515, 'TIMES SQ-42 ST', 8), (31644, '34 ST-HERALD SQ', 16), (25494, 'LEXINGTON AV/53', 8), (25197, '34 ST-PENN STA', 8), (24590, '14 ST-UNION SQ', 9), (23718, '42 ST-PORT AUTH', 16), (23635, '86 ST', 16)]
# [(42956, '34 ST-PENN STA', 16), (40317, '34 ST-HERALD SQ', 8), (38638, '47-50 STS ROCK', 8), (37499, 'TIMES SQ-42 ST', 8), (35850, 'GRD CNTRL-42 ST', 8), (32800, '34 ST-HERALD SQ', 16), (28049, '14 ST-UNION SQ', 9), (26244, 'LEXINGTON AV/53', 8), (24724, '34 ST-PENN STA', 8), (23977, '59 ST', 8)]
# [(44314, '34 ST-PENN STA', 16), (39550, '34 ST-HERALD SQ', 8), (37672, 'TIMES SQ-42 ST', 8), (36831, '47-50 STS ROCK', 8), (34552, '34 ST-HERALD SQ', 16), (26522, '14 ST-UNION SQ', 9), (25649, '34 ST-PENN STA', 8), (25363, 'TIMES SQ-42 ST', 16), (24926, 'LEXINGTON AV/53', 8), (24325, '34 ST-HERALD SQ', 12)]
# [(39820, '34 ST-PENN STA', 16), (37654, '34 ST-HERALD SQ', 8), (34126, 'TIMES SQ-42 ST', 8), (33362, '34 ST-HERALD SQ', 16), (33205, '47-50 STS ROCK', 8), (26315, '34 ST-PENN STA', 12), (26315, '34 ST-HERALD SQ', 12), (25527, '34 ST-PENN STA', 8), (25500, 'TIMES SQ-42 ST', 16), (24896, '14 ST-UNION SQ', 9)]

# %%
station_list = []
total_dict = dict()
for i in range(12,17):
    start_time = dt(2017,6,i,16,0,0)
    end_time = dt(2017,6,i,20,0,0)
    for key in bigDict:
        if key not in total_dict:
            total_dict[key] = stationRiders(bigDict[key],start_time,end_time)
        else:
            total_dict[key] += stationRiders(bigDict[key],start_time,end_time)
    for key, num in total_dict.items():
        station_list.append((num, key))
station_list.sort(reverse=True)
print(station_list[:10])
# Out:
# [(79800, ('R238', 'R046', 'GRD CNTRL-42 ST')), (67903, ('R249', 'R179', '86 ST')), (65174, ('H009', 'R235', 'BEDFORD AV')), (64628, ('R238', 'R046', 'GRD CNTRL-42 ST')), (63473, ('N063A', 'R011', '42 ST-PORT AUTH')), (57943, ('R135', 'R031', '34 ST-PENN STA')), (57925, ('R533', 'R055', 'FLUSHING-MAIN')), (57853, ('R249', 'R179', '86 ST')), (54108, ('N324', 'R018', 'JKSN HT-ROOSVLT')), (52388, ('H009', 'R235', 'BEDFORD AV'))]

# %%
smallDict = {}
for _,key in station_list[:18]:
    smallDict[key] = bigDict[key]

for i in range(10,12):
    wkend_list = []
    for j in range(20):
        start_time = dt(2017,6,i,j,0,0)
        end_time = dt(2017,6,i,j+4,0,0)
        total_dict = dict()
        for key in smallDict:
            station = key[2]
            if station not in total_dict:
                total_dict[station] = stationRiders(smallDict[key],start_time,end_time)
            else:
                total_dict[station] += stationRiders(smallDict[key],start_time,end_time)
        for station, num in total_dict.items():
            wkend_list.append((num, station, start_time.hour))
    wkend_list.sort(reverse=True)
    print(wkend_list[:10])
# Out:
# [(13170, 'BEDFORD AV', 12), (10970, 'BEDFORD AV', 16), (10931, '34 ST-HERALD SQ', 12), (8813, '34 ST-HERALD SQ', 16), (7578, '34 ST-HERALD SQ', 8), (7417, 'GRD CNTRL-42 ST', 12), (6709, 'FLUSHING-MAIN', 16), (6660, 'GRD CNTRL-42 ST', 16), (6141, 'GRD CNTRL-42 ST', 8), (6057, 'JKSN HT-ROOSVLT', 16)]
# [(2038817203, '34 ST-HERALD SQ', 8), (10187, '34 ST-HERALD SQ', 12), (9020, '34 ST-HERALD SQ', 16), (8442, 'BEDFORD AV', 12), (8194, 'BEDFORD AV', 16), (6562, 'GRD CNTRL-42 ST', 12), (6127, 'GRD CNTRL-42 ST', 16), (6060, '34 ST-PENN STA', 12), (5950, '86 ST', 12), (5817, 'FLUSHING-MAIN', 16)]

# %%
station_list = [] 
total_dict = dict()
for i in range(12,17):
     start_time = dt(2017,6,i,15,0,0)
     end_time = dt(2017,6,i,19,0,0)
     for key in bigDict:
        station = key[2]
        if station not in total_dict:
             total_dict[station] = stationRiders(bigDict[key],start_time,end_time)
        else:
             total_dict[station] += stationRiders(bigDict[key],start_time,end_time)
     for station, num in total_dict.items():
             station_list.append((num, station))
station_list.sort(reverse=True)
print(station_list[:10])
# Out:
# [(26604, 'FULTON ST'), (21028, 'FULTON ST'), (15448, 'FULTON ST'), (10089, 'FULTON ST'), (5012, 'FULTON ST'), (0, 'ZEREGA AV'), (0, 'ZEREGA AV'), (0, 'ZEREGA AV'), (0, 'ZEREGA AV'), (0, 'ZEREGA AV')]

# %% [markdown]
# ### How can you use what you have done so far to make decisions about MTA advertising???
